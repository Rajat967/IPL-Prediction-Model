# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\rajat\appdata\local\programs\python\python310\lib\site-packages (1.7.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\rajat\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\rajat\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rajat\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rajat\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder 
import joblib
import os

# %%
df = pd.read_csv("IPL.csv",low_memory=False)

# %%
df["season"] = pd.to_numeric(df["season"], errors="coerce")
df = df.dropna(subset=["season"])
df = df[(df["season"] >= 2020) & (df["season"] <= 2025)]

# %%
df = df[df["innings"] <= 2]

# %%
df = df.dropna(subset=["batting_team", "bowling_team", "batter", "bowler"])

# %%
df["runs"] = df["runs_batter"] + df["runs_extras"]

# %%
df["current_score"] = df.groupby(["match_id", "innings"])["runs"].cumsum()

# %%
df["wickets"] = df["bowler_wicket"].fillna(0).astype(int)
df["wickets"] = df.groupby(["match_id", "innings"]) ["wickets"].cumsum()

# %%
all_teams = pd.concat([df["batting_team"], df["bowling_team"]]).unique()

# %%
team_encoder = LabelEncoder()
team_encoder.fit(all_teams)
# Out:
# LabelEncoder()
